# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Notebook\laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.head(2)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz  8GB            128GB SSD
# 1  Intel Core i5 1.8GHz  8GB  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg  47895.5232

# %%
df['Unnamed: 0']
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1298    1298
# 1299    1299
# 1300    1300
# 1301    1301
# 1302    1302
# Name: Unnamed: 0, Length: 1303, dtype: int64

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df['Ram']=df['Ram'].str.strip("GB")
df['Weight']=df['Weight'].str.replace("kg","")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df['Ram']=df['Ram'].astype("int32")
df['Weight']=df['Weight'].astype("float32")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13128\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.histplot(df['Price'],kde=True,bins=20)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=df['Company'],y=df['Price'],hue=df['Company'])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
df['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=df['Price'],x=df['TypeName'],hue=df['TypeName'])
# Out:
# <Axes: xlabel='TypeName', ylabel='Price'>

# %%
sns.kdeplot(df['Inches'])
# Out:
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.histplot(df['Inches'],kde=True)
# Out:
# <Axes: xlabel='Inches', ylabel='Count'>

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# 2560x1440                                          3
# Touchscreen 2400x1600                              3
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df.sample(5) # Randomly 5
# Out:
#      Company            TypeName  Inches  \
# 573   Lenovo            Notebook    15.6
# 627   Lenovo            Notebook    15.6
# 1107  Lenovo  2 in 1 Convertible    15.6
# 1109    Asus              Gaming    15.6
# 1302    Asus            Notebook    15.6
#
#                                ScreenResolution  \
# 573                           Full HD 1920x1080
# 627                           Full HD 1920x1080
# 1107  IPS Panel Full HD / Touchscreen 1920x1080
# 1109                IPS Panel Full HD 1920x1080
# 1302                                   1366x768
#
#                                        Cpu  Ram                Memory  \
# 573             Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 627             Intel Core i5 7200U 2.5GHz    4             128GB SSD
# 1107            Intel Core i5 6200U 2.3GHz    4             256GB SSD
# 1109           Intel Core i7 6700HQ 2.6GHz   16  128GB SSD +  1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4             500GB HDD
#
#                           Gpu       OpSys  Weight     Price
# 573     Intel HD Graphics 620  Windows 10    2.30  44222.40
# 627     Intel HD Graphics 620       No OS    2.20  24935.04
# 1107    Intel HD Graphics 520  Windows 10    2.10  46193.76
# 1109  Nvidia GeForce GTX 960M  Windows 10    2.59  71341.92
# 1302        Intel HD Graphics  Windows 10    2.20  19660.32

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x: 1 if "Touchscreen" in x else 0)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 962     Acer  Notebook    15.6            Full HD 1920x1080
# 284     Acer  Notebook    15.6  IPS Panel Full HD 1920x1080
# 593  Samsung  Notebook    15.6            Full HD 1920x1080
# 770     Dell  Notebook    15.6            Full HD 1920x1080
# 318       HP  Notebook    14.0            Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 962   Intel Core i5 7200U 2.5GHz   12  128GB SSD +  1TB HDD
# 284   Intel Core i7 8550U 1.8GHz    8             256GB SSD
# 593  Intel Core i7 7700HQ 2.8GHz   16  128GB SSD +  1TB HDD
# 770   Intel Core i7 7500U 2.7GHz   16             256GB SSD
# 318   Intel Core i5 7200U 2.5GHz    8             256GB SSD
#
#                          Gpu       OpSys  Weight       Price  Touchscreen
# 962  Nvidia GeForce GTX 950M  Windows 10    2.40  53759.5200            0
# 284     Nvidia GeForce MX150  Windows 10    3.00  50669.2800            0
# 593  Nvidia GeForce GTX 1050  Windows 10    2.50  90522.7200            0
# 770       AMD Radeon R7 M445  Windows 10    2.30  62938.0656            0
# 318    Intel HD Graphics 620  Windows 10    1.95  52214.4000            0

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
df['Ips']=df['ScreenResolution'].apply(lambda x:1 if "IPS" in x else 0)

# %%
sns.barplot(x=df['Ips'],y=df['Price'],hue=df['Ips'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1

# %% [markdown]
# 1. 'x': This is the delimiter. The code will look for the character 'x' in each string in the 'ScreenResolution' column and split the string at that point.
# 2. n=1: This argument tells the function to perform a maximum of one split.
# 3. expand=True: This is a crucial argument. When set to True, the split strings are expanded into separate columns, creating a new DataFrame

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
df['X_res']=new[0]
df['Y_res']=new[1]
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#                            X_res Y_res
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
df['X_res']=df['X_res'].str.extract(r"(\d+)")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#   X_res Y_res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# memory usage: 142.6+ KB

# %%
df['X_res']=df['X_res'].astype('int')
df['Y_res']=df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# memory usage: 142.6+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    X_res  Y_res
# 0   2560   1600
# 1   1440    900
# 2   1920   1080
# 3   2880   1800
# 4   2560   1600

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.083832
# Y_res          0.552809
# Name: Price, dtype: float64

# %% [markdown]
# ### PPI stands for Pixels Per Inch

# %%
df['ppi']=(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype("float")
df['ppi']
# Out:
# 0       226.983005
# 1       127.677940
# 2       141.211998
# 3       220.534624
# 4       226.983005
#            ...
# 1298    157.350512
# 1299    276.053530
# 1300    111.935204
# 1301    100.454670
# 1302    100.454670
# Name: ppi, Length: 1303, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
#  15  ppi               1303 non-null   float64
# dtypes: float32(1), float64(3), int32(1), int64(4), object(7)
# memory usage: 152.8+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    X_res  Y_res         ppi
# 0   2560   1600  226.983005
# 1   1440    900  127.677940
# 2   1920   1080  141.211998
# 3   2880   1800  220.534624
# 4   2560   1600  226.983005

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.083832
# Y_res          0.552809
# ppi            0.348331
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  X_res  Y_res         ppi
# 0   71378.6832            0    1   2560   1600  226.983005
# 1   47895.5232            0    0   1440    900  127.677940
# 2   30636.0000            0    0   1920   1080  141.211998
# 3  135195.3360            0    1   2880   1800  220.534624
# 4   96095.8080            0    1   2560   1600  226.983005

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))  #" ".join(...): This joins the three selected words back into a single string, separated by spaces: 'Intel Core i5'

# %%
df['Cpu Name'].unique()
# Out:
# array(['Intel Core i5', 'Intel Core i7', 'AMD A9-Series 9420',
#        'Intel Core i3', 'Intel Core M', 'Intel Atom x5-Z8350',
#        'AMD E-Series E2-9000e', 'Intel Atom x5-Z8300',
#        'AMD E-Series E2-6110', 'AMD A6-Series 9220', 'Intel Celeron Dual',
#        'AMD Ryzen 1700', 'Intel Pentium Quad', 'Intel Atom x5-Z8550',
#        'AMD FX 9830P', 'AMD E-Series 6110', 'Intel Xeon E3-1505M',
#        'AMD E-Series 9000e', 'AMD A10-Series A10-9620P',
#        'AMD A6-Series A6-9220', 'AMD A10-Series 9600P',
#        'AMD A8-Series 7410', 'AMD A12-Series 9720P', 'Intel Celeron Quad',
#        'AMD Ryzen 1600', 'AMD A10-Series 9620P', 'AMD E-Series 7110',
#        'AMD A9-Series A9-9420', 'Intel Xeon E3-1535M',
#        'AMD E-Series E2-9000', 'AMD A6-Series 7310', 'Intel Atom Z8350',
#        'Intel Pentium Dual', 'AMD A12-Series 9700P', 'AMD A4-Series 7210',
#        'AMD FX 8800P', 'Intel Atom X5-Z8350', 'Samsung Cortex A72&A53',
#        'AMD E-Series 9000', 'AMD A9-Series 9410'], dtype=object)

# %%
df['Cpu Name'].value_counts()
# Out:
# Cpu Name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# AMD A9-Series 9410            3
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD E-Series E2-9000e         2
# AMD A10-Series A10-9620P      2
# AMD A6-Series A6-9220         2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1505M           2
# Intel Xeon E3-1535M           2
# Intel Atom X5-Z8350           2
# Intel Atom x5-Z8300           1
# AMD E-Series 6110             1
# AMD E-Series 9000e            1
# AMD E-Series E2-6110          1
# AMD FX 9830P                  1
# AMD Ryzen 1600                1
# Intel Atom Z8350              1
# AMD A6-Series 7310            1
# AMD E-Series E2-9000          1
# AMD A12-Series 9700P          1
# AMD FX 8800P                  1
# AMD A4-Series 7210            1
# Samsung Cortex A72&A53        1
# AMD E-Series 9000             1
# Name: count, dtype: int64

# %%
Cpu_name=df['Cpu Name'].apply(lambda x: "Intel" if "Intel" in x else "AMD")

# %%
Cpu_name.head(5)
# Out:
# 0    Intel
# 1    Intel
# 2    Intel
# 3    Intel
# 4    Intel
# Name: Cpu Name, dtype: object

# %%
sns.barplot(x=Cpu_name,y=df['Price'],hue=Cpu_name)
# Out:
# <Axes: xlabel='Cpu Name', ylabel='Price'>

# %%
df.sample(5)
# Out:
#       Company   TypeName                          Cpu  Ram  \
# 1032      MSI     Gaming  Intel Core i7 7700HQ 2.8GHz    8
# 220      Dell   Notebook   Intel Core i5 8250U 1.6GHz    8
# 966      Dell   Notebook   Intel Core i5 7200U 2.5GHz    4
# 257        HP   Notebook   Intel Core i7 8550U 1.8GHz   16
# 406   Toshiba  Ultrabook   Intel Core i7 6500U 2.5GHz   16
#
#                     Memory                      Gpu       OpSys  Weight  \
# 1032  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10     2.7
# 220              256GB SSD           AMD Radeon 520       Linux     2.2
# 966              500GB HDD    Intel HD Graphics 620  Windows 10     1.9
# 257                1TB HDD     Nvidia GeForce MX150  Windows 10     2.9
# 406              512GB SSD    Intel HD Graphics 520  Windows 10     1.2
#
#           Price  Touchscreen  Ips         ppi       Cpu Name
# 1032  63499.104            0    0  127.335675  Intel Core i7
# 220   36089.208            0    0  141.211998  Intel Core i5
# 966   43956.000            0    0  100.454670  Intel Core i5
# 257   56423.520            0    1  127.335675  Intel Core i7
# 406   93080.160            0    0  165.632118  Intel Core i7

# %%
df['Cpu Name'].unique()
# Out:
# array(['Intel Core i5', 'Intel Core i7', 'AMD A9-Series 9420',
#        'Intel Core i3', 'Intel Core M', 'Intel Atom x5-Z8350',
#        'AMD E-Series E2-9000e', 'Intel Atom x5-Z8300',
#        'AMD E-Series E2-6110', 'AMD A6-Series 9220', 'Intel Celeron Dual',
#        'AMD Ryzen 1700', 'Intel Pentium Quad', 'Intel Atom x5-Z8550',
#        'AMD FX 9830P', 'AMD E-Series 6110', 'Intel Xeon E3-1505M',
#        'AMD E-Series 9000e', 'AMD A10-Series A10-9620P',
#        'AMD A6-Series A6-9220', 'AMD A10-Series 9600P',
#        'AMD A8-Series 7410', 'AMD A12-Series 9720P', 'Intel Celeron Quad',
#        'AMD Ryzen 1600', 'AMD A10-Series 9620P', 'AMD E-Series 7110',
#        'AMD A9-Series A9-9420', 'Intel Xeon E3-1535M',
#        'AMD E-Series E2-9000', 'AMD A6-Series 7310', 'Intel Atom Z8350',
#        'Intel Pentium Dual', 'AMD A12-Series 9700P', 'AMD A4-Series 7210',
#        'AMD FX 8800P', 'Intel Atom X5-Z8350', 'Samsung Cortex A72&A53',
#        'AMD E-Series 9000', 'AMD A9-Series 9410'], dtype=object)

# %%
def fetch_processor(text:str):
    if text=="Intel Core i3" or text=="Intel Core i5" or text=="Intel Core i7":
        return text
    else:
        if text.split()[0]=="Intel":
            return "Other Intel Processor"
        else:
            return "AMD Processor"

# %%
df['Cpu Brand']=df['Cpu Name'].apply(fetch_processor)

# %%
df.sample(5)
# Out:
#      Company            TypeName                         Cpu  Ram     Memory  \
# 696   Lenovo  2 in 1 Convertible  Intel Core i7 7500U 2.7GHz   16  512GB SSD
# 261   Lenovo            Notebook    Intel Core i3 6006U 2GHz    4  256GB SSD
# 933   Lenovo  2 in 1 Convertible  Intel Core i7 6560U 2.2GHz   16    1TB SSD
# 1056      HP            Notebook  Intel Core i5 7200U 2.5GHz    4  500GB HDD
# 360       HP            Notebook    Intel Core i3 6006U 2GHz    4  500GB HDD
#
#                           Gpu       OpSys  Weight     Price  Touchscreen  Ips  \
# 696     Intel HD Graphics 620  Windows 10    1.38  93186.72            1    0
# 261     Intel HD Graphics 520       No OS    2.20  23656.32            0    0
# 933   Intel Iris Graphics 540  Windows 10    1.30  95850.72            1    1
# 1056    Intel HD Graphics 620       No OS    1.96  26586.72            0    0
# 360     Intel HD Graphics 520  Windows 10    1.86  23389.92            0    0
#
#              ppi       Cpu Name      Cpu Brand
# 696   157.350512  Intel Core i7  Intel Core i7
# 261   141.211998  Intel Core i3  Intel Core i3
# 933   276.053530  Intel Core i7  Intel Core i7
# 1056  100.454670  Intel Core i5  Intel Core i5
# 360   100.454670  Intel Core i3  Intel Core i3

# %%
df['Cpu Brand'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Cpu Brand'>

# %%
sns.barplot(x=df['Cpu Brand'],y=df['Price'],hue=df['Cpu Brand'])
plt.xticks(rotation="vertical")
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Intel Core i5'),
#   Text(1, 0, 'Intel Core i7'),
#   Text(2, 0, 'AMD Processor'),
#   Text(3, 0, 'Intel Core i3'),
#   Text(4, 0, 'Other Intel Processor')])

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name      Cpu Brand
# 0  226.983005  Intel Core i5  Intel Core i5
# 1  127.677940  Intel Core i5  Intel Core i5
# 2  141.211998  Intel Core i5  Intel Core i5
# 3  220.534624  Intel Core i7  Intel Core i7
# 4  226.983005  Intel Core i5  Intel Core i5

# %%
df.drop(["Cpu","Cpu Name"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu Brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df["Ram"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df["Price"],hue=df['Ram'],palette='dark:blue')
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu Brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1.0TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
# make me 4 columns as HDD, SSD, Hybrid and Flash_Storage if df["memory" ] have SSD write that integer in SSD (for example 128 SSD in SSD column give value as 128 and 0 in other columns)
# convert GB="" and TB=1000  for example 2TB HDD', '64GB SSD 2000 in HDD and 64 in SSD

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Make a copy to avoid SettingWithCopyWarning
df_processed = df.copy()

# 1. Clean and standardize the 'Memory' column
# Remove '.0' from values like '1.0TB'
df_processed['Memory'] = df_processed['Memory'].astype(str).replace('\.0', '', regex=True)
# Replace 'GB' with an empty string
df_processed['Memory'] = df_processed['Memory'].str.replace('GB', '')
# Replace 'TB' with '000' to convert to GB (1TB = 1000GB)
df_processed['Memory'] = df_processed['Memory'].str.replace('TB', '000')
# Rename 'Flash Storage' to match the desired column name
df_processed['Memory'] = df_processed['Memory'].str.replace('Flash Storage', 'Flash_Storage')

# 2. Initialize the four new columns with a default value of 0
df_processed['HDD'] = 0
df_processed['SSD'] = 0
df_processed['Hybrid'] = 0
df_processed['Flash_Storage'] = 0

# 3. Process each string in the 'Memory' column
# Split the string by ' + ' in case of dual drives
for i, memory_string in enumerate(df_processed['Memory']):
    parts = memory_string.split(' + ')
    for part in parts:
        # Split the part into value and storage type (e.g., '128 SSD')
        components = part.strip().split()
        if len(components) == 2:
            value, storage_type = components
            # Find the correct column and add the value
            if storage_type in ['HDD', 'SSD', 'Hybrid', 'Flash_Storage']:
                # Use .loc to safely assign the value to the correct row and column
                df_processed.loc[i, storage_type] += int(value)

df=df_processed.copy()

# You can now drop the original 'Memory' column if you wish
# df_processed.drop(columns=['Memory'], inplace=True)

# %%
df_processed.sample(10)
# Out:
#      Company            TypeName  Ram               Memory  \
# 636     Dell           Ultrabook    8              256 SSD
# 58       MSI              Gaming   16  256 SSD +  2000 HDD
# 1008      HP            Notebook    8              256 SSD
# 203   Lenovo              Gaming   16  512 SSD +  1000 HDD
# 1271  Lenovo  2 in 1 Convertible   16              512 SSD
# 817       HP             Netbook    4     16 Flash_Storage
# 1256    Asus              Gaming   16  128 SSD +  1000 HDD
# 571       HP            Notebook    8             2000 HDD
# 399   Lenovo           Ultrabook   16             1000 SSD
# 436       HP            Notebook    4              500 HDD
#
#                           Gpu       OpSys  Weight        Price  Touchscreen  \
# 636    Intel UHD Graphics 620  Windows 10    1.23   99580.3200            1
# 58    Nvidia GeForce GTX 1070  Windows 10    2.43  130482.7200            0
# 1008     Nvidia GeForce 930MX  Windows 10    1.64   55904.5728            0
# 203   Nvidia GeForce GTX 1060  Windows 10    3.20   93186.7200            0
# 1271    Intel HD Graphics 520  Windows 10    1.30   79866.7200            1
# 817     Intel HD Graphics 400   Chrome OS    1.23   20512.8000            0
# 1256  Nvidia GeForce GTX 970M  Windows 10    4.00  101232.0000            0
# 571     Intel HD Graphics 405  Windows 10    1.94   20725.9200            0
# 399     Intel HD Graphics 620  Windows 10    1.13  139860.0000            0
# 436     Intel HD Graphics 400  Windows 10    2.10   18488.1600            0
#
#       Ips         ppi              Cpu Brand   HDD   SSD  Hybrid  \
# 636     0  276.053530          Intel Core i5     0   256       0
# 58      0  127.335675          Intel Core i7  2000   256       0
# 1008    0  157.350512          Intel Core i5     0   256       0
# 203     1  141.211998          Intel Core i7  1000   512       0
# 1271    1  276.053530          Intel Core i7     0   512       0
# 817     0  135.094211  Other Intel Processor     0     0       0
# 1256    1  127.335675          Intel Core i7  1000   128       0
# 571     0  111.935204  Other Intel Processor  2000     0       0
# 399     1  209.800683          Intel Core i7     0  1000       0
# 436     0  100.454670  Other Intel Processor   500     0       0
#
#       Flash_Storage
# 636               0
# 58                0
# 1008              0
# 203               0
# 1271              0
# 817              16
# 1256              0
# 571               0
# 399               0
# 436               0

# %%
df.drop(columns=["Memory"],inplace=True,axis=1)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu Brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256       0
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512       0
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.348331
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %% [markdown]
# we get best results by keeping HDD and SSD

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True,axis=1)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu Brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].unique()
# Out:
# array(['Intel Iris Plus Graphics 640', 'Intel HD Graphics 6000',
#        'Intel HD Graphics 620', 'AMD Radeon Pro 455',
#        'Intel Iris Plus Graphics 650', 'AMD Radeon R5',
#        'Intel Iris Pro Graphics', 'Nvidia GeForce MX150',
#        'Intel UHD Graphics 620', 'Intel HD Graphics 520',
#        'AMD Radeon Pro 555', 'AMD Radeon R5 M430',
#        'Intel HD Graphics 615', 'AMD Radeon Pro 560',
#        'Nvidia GeForce 940MX', 'Intel HD Graphics 400',
#        'Nvidia GeForce GTX 1050', 'AMD Radeon R2', 'AMD Radeon 530',
#        'Nvidia GeForce 930MX', 'Intel HD Graphics',
#        'Intel HD Graphics 500', 'Nvidia GeForce 930MX ',
#        'Nvidia GeForce GTX 1060', 'Nvidia GeForce 150MX',
#        'Intel Iris Graphics 540', 'AMD Radeon RX 580',
#        'Nvidia GeForce 920MX', 'AMD Radeon R4 Graphics', 'AMD Radeon 520',
#        'Nvidia GeForce GTX 1070', 'Nvidia GeForce GTX 1050 Ti',
#        'Nvidia GeForce MX130', 'AMD R4 Graphics',
#        'Nvidia GeForce GTX 940MX', 'AMD Radeon RX 560',
#        'Nvidia GeForce 920M', 'AMD Radeon R7 M445', 'AMD Radeon RX 550',
#        'Nvidia GeForce GTX 1050M', 'Intel HD Graphics 515',
#        'AMD Radeon R5 M420', 'Intel HD Graphics 505',
#        'Nvidia GTX 980 SLI', 'AMD R17M-M1-70', 'Nvidia GeForce GTX 1080',
#        'Nvidia Quadro M1200', 'Nvidia GeForce 920MX ',
#        'Nvidia GeForce GTX 950M', 'AMD FirePro W4190M ',
#        'Nvidia GeForce GTX 980M', 'Intel Iris Graphics 550',
#        'Nvidia GeForce 930M', 'Intel HD Graphics 630',
#        'AMD Radeon R5 430', 'Nvidia GeForce GTX 940M',
#        'Intel HD Graphics 510', 'Intel HD Graphics 405',
#        'AMD Radeon RX 540', 'Nvidia GeForce GT 940MX',
#        'AMD FirePro W5130M', 'Nvidia Quadro M2200M', 'AMD Radeon R4',
#        'Nvidia Quadro M620', 'AMD Radeon R7 M460',
#        'Intel HD Graphics 530', 'Nvidia GeForce GTX 965M',
#        'Nvidia GeForce GTX1080', 'Nvidia GeForce GTX1050 Ti',
#        'Nvidia GeForce GTX 960M', 'AMD Radeon R2 Graphics',
#        'Nvidia Quadro M620M', 'Nvidia GeForce GTX 970M',
#        'Nvidia GeForce GTX 960<U+039C>', 'Intel Graphics 620',
#        'Nvidia GeForce GTX 960', 'AMD Radeon R5 520',
#        'AMD Radeon R7 M440', 'AMD Radeon R7', 'Nvidia Quadro M520M',
#        'Nvidia Quadro M2200', 'Nvidia Quadro M2000M',
#        'Intel HD Graphics 540', 'Nvidia Quadro M1000M', 'AMD Radeon 540',
#        'Nvidia GeForce GTX 1070M', 'Nvidia GeForce GTX1060',
#        'Intel HD Graphics 5300', 'AMD Radeon R5 M420X',
#        'AMD Radeon R7 Graphics', 'Nvidia GeForce 920',
#        'Nvidia GeForce 940M', 'Nvidia GeForce GTX 930MX',
#        'AMD Radeon R7 M465', 'AMD Radeon R3', 'Nvidia GeForce GTX 1050Ti',
#        'AMD Radeon R7 M365X', 'AMD Radeon R9 M385',
#        'Intel HD Graphics 620 ', 'Nvidia Quadro 3000M',
#        'Nvidia GeForce GTX 980 ', 'AMD Radeon R5 M330',
#        'AMD FirePro W4190M', 'AMD FirePro W6150M', 'AMD Radeon R5 M315',
#        'Nvidia Quadro M500M', 'AMD Radeon R7 M360',
#        'Nvidia Quadro M3000M', 'Nvidia GeForce 960M', 'ARM Mali T860 MP4'],
#       dtype=object)

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
# df["Gpu Brand Name"]=df['Gpu'].apply(lambda x: "Intel" if "Intel" in x else "Nvidia" if "Nvidia" in x else "AMD" if "AMD" in x else "ARM")

df["Gpu Brand Name"]=df["Gpu"].apply(lambda x: x.split()[0])

# %%
df.sample(10)
# Out:
#      Company            TypeName  Ram                      Gpu       OpSys  \
# 448      MSI              Gaming    8  Nvidia GeForce GTX 1050  Windows 10
# 924   Lenovo  2 in 1 Convertible    8    Intel HD Graphics 620  Windows 10
# 839     Asus            Notebook    8    Intel HD Graphics 620  Windows 10
# 619     Acer  2 in 1 Convertible    4    Intel HD Graphics 400   Chrome OS
# 1057    Acer            Notebook    8            AMD Radeon R5  Windows 10
# 705     Dell            Notebook    8    Intel HD Graphics 620  Windows 10
# 432   Lenovo            Notebook    4    Intel HD Graphics 620  Windows 10
# 510     Dell           Ultrabook    8    Intel HD Graphics 620  Windows 10
# 201   Lenovo            Notebook    4    Intel HD Graphics 520  Windows 10
# 977     Asus  2 in 1 Convertible   16  Nvidia GeForce GTX 950M  Windows 10
#
#       Weight       Price  Touchscreen  Ips         ppi              Cpu Brand  \
# 448     2.20  54757.9872            0    0  141.211998          Intel Core i5
# 924     1.37  97236.0000            1    1  165.632118          Intel Core i5
# 839     2.30  31435.2000            0    0  141.211998          Intel Core i5
# 619     1.25  20193.1200            1    1  135.094211  Other Intel Processor
# 1057    2.40  23922.7200            0    0  100.454670          AMD Processor
# 705     2.18  42357.6000            0    0  141.211998          Intel Core i5
# 432     1.70  31914.7200            0    1  157.350512          Intel Core i3
# 510     1.29  47898.7200            1    1  165.632118          Intel Core i5
# 201     2.10  26267.0400            0    0  100.454670          Intel Core i5
# 977     2.30  95850.7200            1    0  138.461776          Intel Core i7
#
#        HDD  SSD Gpu Brand Name
# 448      0  256         Nvidia
# 924      0  512          Intel
# 839    128    0          Intel
# 619      0    0          Intel
# 1057  1000    0            AMD
# 705      0  256          Intel
# 432      0  128          Intel
# 510      0  128          Intel
# 201      0  128          Intel
# 977   2000  512         Nvidia

# %%
df[df["Gpu Brand Name"]=="ARM"]
# Out:
#       Company            TypeName  Ram                Gpu      OpSys  Weight  \
# 1191  Samsung  2 in 1 Convertible    4  ARM Mali T860 MP4  Chrome OS    1.15
#
#          Price  Touchscreen  Ips       ppi      Cpu Brand  HDD  SSD  \
# 1191  35111.52            1    1  234.5074  AMD Processor    0    0
#
#      Gpu Brand Name
# 1191            ARM

# %%
df=df[df["Gpu Brand Name"]!="ARM"]

# %%
df['Gpu Brand Name'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Gpu Brand Name'>

# %%
sns.barplot(x=df["Gpu Brand Name"],y=df["Price"],hue=df["Gpu Brand Name"])
# Out:
# <Axes: xlabel='Gpu Brand Name', ylabel='Price'>

# %%
df.drop(["Gpu"],inplace=True,axis=1)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu Brand  HDD  SSD Gpu Brand Name
# 0  226.983005  Intel Core i5    0  128          Intel
# 1  127.677940  Intel Core i5    0    0          Intel
# 2  141.211998  Intel Core i5    0  256          Intel
# 3  220.534624  Intel Core i7    0  512            AMD
# 4  226.983005  Intel Core i5    0  256          Intel

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df["OpSys"],y=df["Price"],hue=df["OpSys"])
plt.xticks(rotation="vertical")
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'macOS'),
#   Text(1, 0, 'No OS'),
#   Text(2, 0, 'Windows 10'),
#   Text(3, 0, 'Mac OS X'),
#   Text(4, 0, 'Linux'),
#   Text(5, 0, 'Android'),
#   Text(6, 0, 'Windows 10 S'),
#   Text(7, 0, 'Chrome OS'),
#   Text(8, 0, 'Windows 7')])

# %%
def cat_os(inp):
    if inp=="Windows 10" or inp=='Windows 7' or inp=="Windows 10 S":
        return "Windows"
    elif inp=="macOS" or inp=="Mac OS X":
        return "Mac"
    else:
        return "Others/No Os/Linux"

# %%
df["OS"]=df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu Brand  HDD  SSD Gpu Brand Name                  OS
# 0  226.983005  Intel Core i5    0  128          Intel                 Mac
# 1  127.677940  Intel Core i5    0    0          Intel                 Mac
# 2  141.211998  Intel Core i5    0  256          Intel  Others/No Os/Linux
# 3  220.534624  Intel Core i7    0  512            AMD                 Mac
# 4  226.983005  Intel Core i5    0  256          Intel                 Mac

# %%
df.drop(columns=["OpSys"],inplace=True,axis=1)

# %%
sns.barplot(x=df["OS"],y=df["Price"],hue=df["OS"])
plt.xticks(rotation="vertical")
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Mac'), Text(1, 0, 'Others/No Os/Linux'), Text(2, 0, 'Windows')])

# %%
sns.histplot(x=df["Weight"],kde=True)
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand Name                  OS
# 0  Intel Core i5    0  128          Intel                 Mac
# 1  Intel Core i5    0    0          Intel                 Mac
# 2  Intel Core i5    0  256          Intel  Others/No Os/Linux
# 3  Intel Core i7    0  512            AMD                 Mac
# 4  Intel Core i5    0  256          Intel                 Mac

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(df["Price"],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(np.log(df['Price']),kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
X=df.drop("Price",axis=1)
y=np.log(df["Price"])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
#                   Cpu Brand   HDD  SSD Gpu Brand Name                  OS
# 0             Intel Core i5     0  128          Intel                 Mac
# 1             Intel Core i5     0    0          Intel                 Mac
# 2             Intel Core i5     0  256          Intel  Others/No Os/Linux
# 3             Intel Core i7     0  512            AMD                 Mac
# 4             Intel Core i5     0  256          Intel                 Mac
# ...                     ...   ...  ...            ...                 ...
# 1298          Intel Core i7     0  128          Intel             Windows
# 1299          Intel Core i7     0  512          Intel             Windows
# 1300  Other Intel Processor     0    0          Intel             Windows
# 1301          Intel Core i7  1000    0            AMD             Windows
# 1302  Other Intel Processor   500    0          Intel             Windows
#
# [1302 rows x 12 columns]

# %% [markdown]
# # EDA Completed

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram  Weight       Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37  71378.6832            0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand Name   OS
# 0  Intel Core i5    0  128          Intel  Mac

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## Model Training and Model Selection

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
## Create function to evaluate model
def evaluate_model(true,predict):
    mae=mean_absolute_error(true,predict)
    mse=mean_squared_error(true,predict)
    rmse=root_mean_squared_error(true,predict)
    r2_sqaure=r2_score(true,predict)
    return mae,mse,rmse,r2_sqaure

# %%
models = {
                "Linear Regression": LinearRegression(),
                "Ridge":Ridge(),
                "Lasso":Lasso(),
                "K-Neighbors Regressor": KNeighborsRegressor(),
                "Random Forest": RandomForestRegressor(),
                "Decision Tree": DecisionTreeRegressor(),
                "Gradient Boosting": GradientBoostingRegressor(),
                "AdaBoost Regressor": AdaBoostRegressor(),
                "SVR":SVR(),
                "XGBRegressor":XGBRegressor()
        }

# %%
X.shape
# Out:
# (1302, 12)

# %%
try:
        from sklearn.pipeline import Pipeline
        preprocessor=ColumnTransformer(transformers=[
        ("cl_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
        ],remainder="passthrough")

        X_transformed=preprocessor.fit_transform(X)
        from sklearn.model_selection import train_test_split
        X_train,X_test,y_train,y_test=train_test_split(X_transformed,y,test_size=0.15,random_state=2)


        r2_list=[]
        model_list=[]
        for i in range(len(list(models))):
                model=list(models.values())[i]
                model.fit(X_train,y_train)

         #Make predicitons
                y_train_pred=model.predict(X_train)
                y_test_pred=model.predict(X_test)

        # Evaluate Train and Test dataset
                model_train_mae,model_train_mse, model_train_rmse, model_train_r2 = evaluate_model(y_train,y_train_pred)
                model_test_mae,model_test_mse, model_test_rmse, model_test_r2 = evaluate_model(y_test,y_test_pred)
        
                print(list(models.keys())[i])
                model_list.append(list(models.keys())[i])

                print("Model preformance for Training set")
                print("Root Mean Squared Error: ",model_train_rmse)
                print("Mean Absolute Error: ",model_train_mae)
                print("R2 Score: ",model_train_r2)

                print("--------------------------")

                print("Model preformance for Test set")
                print("Root Mean Squared Error: ",model_test_rmse)
                print("Mean Absolute Error: ",model_test_mae)
                print("R2 Score: ",model_test_r2)
                r2_list.append(model_test_r2)

                print('='*35)
                print('\n')
                
except Exception as e:
        raise e
# Out:
# Linear Regression
# Model preformance for Training set
# Root Mean Squared Error:  0.2535632485524274
# Mean Absolute Error:  0.19880311867473133
# R2 Score:  0.8351374505441622
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.28598383932112226
# Mean Absolute Error:  0.2163309022678095
# R2 Score:  0.7862069874164868
# ===================================
#
#
# Ridge
# Model preformance for Training set
# Root Mean Squared Error:  0.25412011418622665
# Mean Absolute Error:  0.19913553725201183
# R2 Score:  0.8344125260979205
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.2839335251470426
# Mean Absolute Error:  0.2156154775677565
# R2 Score:  0.7892615063818692
# ===================================
#
#
# Lasso
# Model preformance for Training set
# Root Mean Squared Error:  0.4354677309547981
# Mean Absolute Error:  0.3484122783898813
# R2 Score:  0.5137480520791553
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.43159391761181964
# Mean Absolute Error:  0.33751521623327313
# R2 Score:  0.5130760305858479
# ===================================
#
#
# K-Neighbors Regressor
# Model preformance for Training set
# Root Mean Squared Error:  0.23146609107180563
# Mean Absolute Error:  0.17075988635495248
# R2 Score:  0.8626197974972608
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.28125524124664303
# Mean Absolute Error:  0.205046513288553
# R2 Score:  0.7932184572197432
# ===================================
#
#
# Random Forest
# Model preformance for Training set
# Root Mean Squared Error:  0.08569101890826093
# Mean Absolute Error:  0.06416132086577944
# R2 Score:  0.9811713140858728
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.21060698532957062
# Mean Absolute Error:  0.1577864981034538
# R2 Score:  0.8840539212074784
# ===================================
#
#
# Decision Tree
# Model preformance for Training set
# Root Mean Squared Error:  0.03870646966884312
# Mean Absolute Error:  0.011108950381620582
# R2 Score:  0.9961583612673353
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.2758404224769092
# Mean Absolute Error:  0.20007680672139777
# R2 Score:  0.8011038662564469
# ===================================
#
#
# Gradient Boosting
# Model preformance for Training set
# Root Mean Squared Error:  0.19458291342967196
# Mean Absolute Error:  0.15157953962455803
# R2 Score:  0.9029135099106133
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.2231514127086241
# Mean Absolute Error:  0.17426377193318676
# R2 Score:  0.8698303300487862
# ===================================
#
#
# AdaBoost Regressor
# Model preformance for Training set
# Root Mean Squared Error:  0.2670529641643403
# Mean Absolute Error:  0.22198197049994095
# R2 Score:  0.8171292681876983
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.27137622229092395
# Mean Absolute Error:  0.22504149086154207
# R2 Score:  0.8074896393502846
# ===================================
#
#
# SVR
# Model preformance for Training set
# Root Mean Squared Error:  0.38985285649859835
# Mean Absolute Error:  0.3012835027472803
# R2 Score:  0.6102816648125764
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.38659477589410224
# Mean Absolute Error:  0.2936282878861722
# R2 Score:  0.6093188255292619
# ===================================
#
#
# XGBRegressor
# Model preformance for Training set
# Root Mean Squared Error:  0.07074145838679963
# Mean Absolute Error:  0.05019578801463205
# R2 Score:  0.9871679094668199
# --------------------------
# Model preformance for Test set
# Root Mean Squared Error:  0.20690063591954125
# Mean Absolute Error:  0.1514538004644894
# R2 Score:  0.888098946946309
# ===================================

# %%
X_train.shape
# Out:
# (1106, 38)

# %%
model_list
# Out:
# ['Linear Regression',
#  'Ridge',
#  'Lasso',
#  'K-Neighbors Regressor',
#  'Random Forest',
#  'Decision Tree',
#  'Gradient Boosting',
#  'AdaBoost Regressor',
#  'SVR',
#  'XGBRegressor']

# %%
pd.DataFrame(list(zip(model_list,r2_list)),columns=["Model Name","R2 Score"]).sort_values(by=["R2 Score"],ascending=False)
# Out:
#               Model Name  R2 Score
# 9           XGBRegressor  0.888099
# 4          Random Forest  0.884054
# 6      Gradient Boosting  0.869830
# 7     AdaBoost Regressor  0.807490
# 5          Decision Tree  0.801104
# 3  K-Neighbors Regressor  0.793218
# 1                  Ridge  0.789262
# 0      Linear Regression  0.786207
# 8                    SVR  0.609319
# 2                  Lasso  0.513076

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train.shape
# Out:
# (1106, 12)

# %%
from sklearn.pipeline import Pipeline
step1=ColumnTransformer(transformers=[
    ("cl_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],remainder="passthrough")

step2=RandomForestRegressor()
pipe=Pipeline(steps=[
    ("step1",step1),
    ("step2",step2)

])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

# %%
X_train.shape
# Out:
# (1106, 12)

# %%
y_pred
# Out:
# array([10.6427227 ,  9.71357755,  9.73076232, 10.14978025, 11.32514113,
#        11.51557581, 10.05273173, 10.78294477, 11.1226118 ,  9.70402556,
#        11.27731312, 10.82117468, 11.50045667, 10.82170886, 11.58192202,
#        11.05987901, 11.01960881,  9.77229155, 11.54615616, 11.52686979,
#        11.51729814, 11.32696287, 10.53112472, 10.9481166 , 10.23787893,
#        11.55417303, 11.01601718, 10.04980259, 10.97912384, 10.45410779,
#        11.23175228, 10.15893338, 10.82036376, 10.941983  , 11.03243575,
#        10.7271325 , 11.32618775, 11.19139805, 11.51467154, 11.36255199,
#        11.54337404, 11.07768347,  9.83343542,  9.8009478 , 10.11957125,
#         9.92823361, 10.78838292, 11.54647349, 11.48776758, 11.1517464 ,
#        11.69834287, 11.52127562,  9.95070927,  9.34946049, 10.39656977,
#        10.79828986, 10.02744373, 11.12645879,  9.99679873, 10.46448118,
#        11.25163045, 11.00657573,  9.4869547 , 11.24314124, 10.97954557,
#        10.54848499, 10.02957595, 11.03559161, 10.76364448,  9.81242494,
#        10.93569552, 10.52479773, 10.60084825, 10.44926274, 11.29929775,
#        10.82951594, 11.24280233, 12.03472252, 11.27430382, 10.54392077,
#        10.8809513 , 11.07302781, 11.41955405, 10.06984166, 11.25329255,
#        10.39899627, 10.92272061, 11.47539089, 10.05037733, 10.69073484,
#        10.3888631 , 10.22301458, 10.61764953, 11.54263128, 10.23843365,
#         9.66145847, 10.45367852, 10.28786497,  9.78559781, 11.52055867,
#        10.51045224, 11.19325647, 10.02735245, 11.69795444, 10.82487385,
#        11.13733415, 11.29299111, 10.1784256 , 10.83966101,  9.88014082,
#        10.73317235, 10.95978129, 10.47840873, 11.52497056, 10.1030563 ,
#        10.6427227 ,  9.87171434, 11.72671146, 10.58443853, 10.76753614,
#        10.43764444, 11.74535326, 10.96316111, 10.40896816, 10.52105813,
#        11.20135104, 10.4687863 ,  9.88151099, 11.42404488, 11.51885074,
#        10.42048609, 11.07478407, 10.33584006, 11.1601204 , 11.18102348,
#        10.43500739, 11.1075208 , 11.13733415, 11.1244167 , 11.52497056,
#         9.86191261,  9.51052873, 10.78200984, 10.38044865, 10.65670785,
#        11.44457497, 10.71555975,  9.80985224, 11.33222884, 10.39721449,
#        11.78809175, 11.30226726, 10.86087127, 10.96766239, 11.0976813 ,
#        10.55384746, 10.96687301, 11.83434134, 11.05626823, 11.36994395,
#         9.43168171, 10.10277893, 10.72748118, 10.52113102, 11.07321995,
#        11.22285072, 11.5667701 , 10.18961038, 11.44201344, 11.12996812,
#        10.1256518 , 11.02500308, 10.02730476, 11.13001534, 10.93928199,
#        10.93261083, 11.53492397, 11.63154997, 11.04705047, 10.13964898,
#        10.70906347, 11.047861  , 11.1095094 , 10.64565061, 10.09105499,
#        10.80169674, 10.6535381 , 11.46086033, 10.8149222 ,  9.90410744,
#        10.07646987, 11.18544793,  9.72763523, 11.04360779, 11.33250163,
#        11.42273665])

# %%
X_train.shape
# Out:
# (1106, 12)

# %% [markdown]
# ### Difference Between Acutal and Predicated Values

# %%
pred_df=pd.DataFrame({"Acutal Value":y_test,"Predicated Value":y_test_pred,"Difference":y_test-y_test_pred})

# %%
pred_df
# Out:
#       Acutal Value  Predicated Value  Difference
# 248      10.490274         10.541154   -0.050880
# 555       9.387207          9.713624   -0.326417
# 1251      9.964522          9.767116    0.197407
# 547      10.111883         10.133307   -0.021423
# 885      11.470547         11.486195   -0.015647
# ...            ...               ...         ...
# 1129     11.004649         11.034789   -0.030140
# 172       9.708902          9.735894   -0.026992
# 322      10.973157         10.968766    0.004391
# 996      11.182680         11.340249   -0.157569
# 470      11.575963         11.415548    0.160415
#
# [196 rows x 3 columns]

# %% [markdown]
# ## Exporting The Model

# %%
import pickle

pickle.dump(df,open("df.pkl","wb"))
pickle.dump(pipe,open("pipe.pkl","wb"))

# %%
df["Company"].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand Name                  OS
# 0  Intel Core i5    0  128          Intel                 Mac
# 1  Intel Core i5    0    0          Intel                 Mac
# 2  Intel Core i5    0  256          Intel  Others/No Os/Linux
# 3  Intel Core i7    0  512            AMD                 Mac
# 4  Intel Core i5    0  256          Intel                 Mac

# %%
df["Cpu Brand"].unique()
# Out:
# array(['Intel Core i5', 'Intel Core i7', 'AMD Processor', 'Intel Core i3',
#        'Other Intel Processor'], dtype=object)

# %%
df['Gpu Brand Name'].unique()
# Out:
# array(['Intel', 'AMD', 'Nvidia'], dtype=object)

# %%
X_test.shape
# Out:
# (196, 12)

# %%
pd.DataFrame(X_test)
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 248       HP            Notebook    4    1.49            0    1  165.632118
# 555     Asus            Notebook    4    2.00            0    0  100.454670
# 1251      HP            Notebook    4    1.86            0    0  100.454670
# 547   Lenovo            Notebook    4    2.15            0    0  141.211998
# 885       HP  2 in 1 Convertible    4    1.28            1    0  165.632118
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1129      HP              Gaming    8    3.35            0    1  127.335675
# 172   Lenovo            Notebook    4    2.20            0    0  100.454670
# 322     Asus            Notebook    8    2.00            0    0  157.350512
# 996       HP           Ultrabook    8    1.11            1    1  165.632118
# 470       HP  2 in 1 Convertible    8    1.29            1    1  162.406294
#
#                   Cpu Brand   HDD  SSD Gpu Brand Name                  OS
# 248           Intel Core i5   500    0          Intel             Windows
# 555   Other Intel Processor   500    0          Intel  Others/No Os/Linux
# 1251          AMD Processor   500    0            AMD             Windows
# 547           Intel Core i5  1000    0          Intel  Others/No Os/Linux
# 885           Intel Core i5     0  256          Intel             Windows
# ...                     ...   ...  ...            ...                 ...
# 1129          Intel Core i5  1000  128         Nvidia             Windows
# 172           AMD Processor   500    0            AMD  Others/No Os/Linux
# 322           Intel Core i7     0  256          Intel             Windows
# 996           Intel Core i7     0  256          Intel             Windows
# 470           Intel Core i7     0  512          Intel             Windows
#
# [196 rows x 12 columns]

# %%
pipe.predict(X_test)
# Out:
# array([10.6427227 ,  9.71357755,  9.73076232, 10.14978025, 11.32514113,
#        11.51557581, 10.05273173, 10.78294477, 11.1226118 ,  9.70402556,
#        11.27731312, 10.82117468, 11.50045667, 10.82170886, 11.58192202,
#        11.05987901, 11.01960881,  9.77229155, 11.54615616, 11.52686979,
#        11.51729814, 11.32696287, 10.53112472, 10.9481166 , 10.23787893,
#        11.55417303, 11.01601718, 10.04980259, 10.97912384, 10.45410779,
#        11.23175228, 10.15893338, 10.82036376, 10.941983  , 11.03243575,
#        10.7271325 , 11.32618775, 11.19139805, 11.51467154, 11.36255199,
#        11.54337404, 11.07768347,  9.83343542,  9.8009478 , 10.11957125,
#         9.92823361, 10.78838292, 11.54647349, 11.48776758, 11.1517464 ,
#        11.69834287, 11.52127562,  9.95070927,  9.34946049, 10.39656977,
#        10.79828986, 10.02744373, 11.12645879,  9.99679873, 10.46448118,
#        11.25163045, 11.00657573,  9.4869547 , 11.24314124, 10.97954557,
#        10.54848499, 10.02957595, 11.03559161, 10.76364448,  9.81242494,
#        10.93569552, 10.52479773, 10.60084825, 10.44926274, 11.29929775,
#        10.82951594, 11.24280233, 12.03472252, 11.27430382, 10.54392077,
#        10.8809513 , 11.07302781, 11.41955405, 10.06984166, 11.25329255,
#        10.39899627, 10.92272061, 11.47539089, 10.05037733, 10.69073484,
#        10.3888631 , 10.22301458, 10.61764953, 11.54263128, 10.23843365,
#         9.66145847, 10.45367852, 10.28786497,  9.78559781, 11.52055867,
#        10.51045224, 11.19325647, 10.02735245, 11.69795444, 10.82487385,
#        11.13733415, 11.29299111, 10.1784256 , 10.83966101,  9.88014082,
#        10.73317235, 10.95978129, 10.47840873, 11.52497056, 10.1030563 ,
#        10.6427227 ,  9.87171434, 11.72671146, 10.58443853, 10.76753614,
#        10.43764444, 11.74535326, 10.96316111, 10.40896816, 10.52105813,
#        11.20135104, 10.4687863 ,  9.88151099, 11.42404488, 11.51885074,
#        10.42048609, 11.07478407, 10.33584006, 11.1601204 , 11.18102348,
#        10.43500739, 11.1075208 , 11.13733415, 11.1244167 , 11.52497056,
#         9.86191261,  9.51052873, 10.78200984, 10.38044865, 10.65670785,
#        11.44457497, 10.71555975,  9.80985224, 11.33222884, 10.39721449,
#        11.78809175, 11.30226726, 10.86087127, 10.96766239, 11.0976813 ,
#        10.55384746, 10.96687301, 11.83434134, 11.05626823, 11.36994395,
#         9.43168171, 10.10277893, 10.72748118, 10.52113102, 11.07321995,
#        11.22285072, 11.5667701 , 10.18961038, 11.44201344, 11.12996812,
#        10.1256518 , 11.02500308, 10.02730476, 11.13001534, 10.93928199,
#        10.93261083, 11.53492397, 11.63154997, 11.04705047, 10.13964898,
#        10.70906347, 11.047861  , 11.1095094 , 10.64565061, 10.09105499,
#        10.80169674, 10.6535381 , 11.46086033, 10.8149222 ,  9.90410744,
#        10.07646987, 11.18544793,  9.72763523, 11.04360779, 11.33250163,
#        11.42273665])
